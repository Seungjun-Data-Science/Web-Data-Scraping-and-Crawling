# %% [markdown]
# # Web Scraping with python requests, urllib and BeautifulSoup

# %% [markdown]
# Web Scraping tutorial using python's requests library and BeautifulSoup. Going to scrape global news section of Reuters news. Retrieving four things from each article: title, firstline of article, url link of the article and when the article was written

# %% [markdown]
# ### Method 1 : Using python requests and BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.reuters.com/news/archive/worldNews?view=page'

# %%
result = requests.get(url)

# %%
result.status_code

# Checking if there is no problem with the request
# Out:
# 200

# %%
result.raise_for_status()

# prints None if there is no problem with the request. Otherwise, it raises an error

# %%
result.status_code == requests.codes.ok

# prints True if there is no problem with the request
# Out:
# True

# %%
content = result.content

# %%
# decoding, removing whitespaces and tabs. Lastly, spliting by new line
# To view the structure of the html and determine which tags to extract
content.decode().strip().replace('\t','').split('\n')
# Out:
# ['<!--[if !IE]> This has been served from cache <![endif]-->',
#  '<!--[if !IE]> Request served from apache server: produs--i-ede3bd7e <![endif]-->',
#  '<!--[if !IE]> Cached on Sat, 17 Jun 2017 13:37:13 GMT and will expire on Sat, 17 Jun 2017 13:42:20 GMT <![endif]-->',
#  '<!--[if !IE]> token: 85f27e91-1f6a-4c48-af2c-7f02ce75a87f <![endif]-->',
#  '<!--[if !IE]> Tomcat Server /produs--i-04d0ea63c73100166/ <![endif]-->',
#  '',
#  '<!--[if !IE]> App Server /produs--i-04d0ea63c73100166/ <![endif]-->',
#  '',
#  '<!doctype html><html lang="en"><head>',
#  '<title>World News Headlines  | Reuters</title>',
#  '    <meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta http-equiv="x-dns-prefetch-control" content="on"><link rel="dns-prefetch" href="//s1.reutersmedia.net"/><link rel="dns-prefetch" href="//s2.reutersmedia.net"/><link rel="dns-prefetch" href="//s3.reutersmedia.net"/><link rel="dns-prefetch" href="//s4.reutersmedia.net"/><link rel="dns-prefetch" href="//static.reuters.com"/><link rel="dns-prefetch" href="//www.googletagservices.com"/><link rel="dns-prefetch" href="//www.googletagmanager.com"/><link rel="dns-prefetch" href="//www.google-analytics.com"/><link rel="dns-prefetch" href="//static.chartbeat.com"/><meta name="robots" content="INDEX, FOLLOW">',
#  '',
#  '<!-- Page hiding snippet  -->',
#  '<style>.async-hide { opacity: 0 !important} </style>',
#  '<script>',
#  "(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;",
#  "h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};",
#  '(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);',
#  "})(window,document.documentElement,'async-hide','dataLayer',2000,{'GTM-W9SLGS':true});",
#  '</script> ',
#  '',
#  '<!-- Data Layer Object Declaration -->',
#  '<script>',
#  '    window.dataLayer = window.dataLayer || [];',
#  '</script>',
#  '',
#  '<!-- New Google Tag Manager -->',
#  '<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(',
#  "    {'gtm.start': new Date().getTime(),event:'gtm.js'}",
#  '    );var f=d.getElementsByTagName(s)[0],',
#  "    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=",
#  "    'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);",
#  "    })(window,document,'script','dataLayer','GTM-W9SLGS');</script>",
#  '<!-- End Google Tag Manager -->',
#  '',
#  '<meta name="google-site-verification" content="SVDMcE-27ZUUuh-EcZzejAJ0YIFjxD9H_nwAX6YVTw4" /><meta name="msvalidate.01" content="2055F771212E9574BFD5AF29D47FBA04" /><script type="text/javascript" >',
#  '',
#  '// Rubicon Initialize',
#  '(function() {',
#  '    var account_id = 11384;',
#  "    var rct = document.createElement('script');",
#  "        rct.type = 'text/javascript';",
#  '        rct.async = true;',
#  "        rct.src = (document.location.protocol === 'https:' ? 'https:' : 'http:') + '//ads.rubiconproject.com/header/' + account_id + '.js';",
#  "    var node = document.getElementsByTagName('script')[0];",
#  '        node.parentNode.appendChild(rct);',
#  '})();',
#  '',
#  '</script><script type="text/javascript" src="//reuters-d.openx.net/w/1.0/jstag?nc=4735792-reuters"></script><div class="linebreak"></div>',
#  '<style>',
#  "@font-face { font-family: 'knowledge-reg'; src: url('/resources_v2/fonts/Knowledge-Regular.woff') format('woff'); font-weight: normal; font-style: normal; }",
#  "@font-face { font-family: 'knowledge-light'; src: url('/resources_v2/fonts/Knowledge-Light.woff') format('woff'); font-weight: normal; font-style: normal; }",
#  "@font-face { font-family: 'knowledge-medium'; src: url('/resources_v2/fonts/Knowledge-Medium.woff') format('woff'); font-weight: normal; font-style: normal; }",
#  '</style>',
#  '',
#  '<script type="text/javascript" src="//www.reuters.com/reuters_bootstrap.js"></script><script type="text/javascript" src="//www.reuters.com/reuters_gpt_bootstrap.js"></script>',
#  '<script type="text/javascript">var abp;</script><script type="text/javascript" src="https://s4.reutersmedia.net/resources_v2/js/px.js?ch=1"></script><script type="text/javascript" src="https://s4.reutersmedia.net/resources_v2/js/px.js?ch=2"></script>',
#  '<script type="text/javascript">',
#  'var parallelMediaHosts = new Array();',
#  'parallelMediaHosts.push("s1.reutersmedia.net");parallelMediaHosts.push("s2.reutersmedia.net");parallelMediaHosts.push("s3.reutersmedia.net");parallelMediaHosts.push("s4.reutersmedia.net");</script>',
#  '',
#  '<meta name="site edition" content="Reuters" />',
#  '<link rel="canonical" href="http://www.reuters.com/news/archive/worldNews" />',
#  '<meta name="Author" content="Reuters Editorial" />',
#  '<meta name="description" content="Get the latest breaking news and top news headlines at Reuters.com" />',
#  '<meta name="keywords" content="top news,breaking news,latest news,news headlines" />',
#  '<meta name="twitter:card" content="summary_large_image" /> ',
#  '<meta name="twitter:description" content="Get the latest breaking news and top news headlines at Reuters.com" />',
#  '<meta name="twitter:image:src" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png">',
#  '<meta name="twitter:image" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png" />',
#  '<meta name="twitter:site" content="@Reuters" />',
#  '<meta name="twitter:creator" content="@Reuters" />',
#  '<link rel="publisher" href="https://plus.google.com/+Reuters" />',
#  '    <meta property="og:locale" content="en_US" />',
#  '<meta property="og:site_name" content="Reuters" />',
#  '<meta property="og:title" content="Breaking News, Top News & Latest News Headlines | Reuters" />',
#  '<meta property="og:url" content="http://www.reuters.com/news/archive/worldNews" />',
#  '<meta property="og:type" content="section" />',
#  '<meta property="og:description" content="Get the latest breaking news and top news headlines at Reuters.com" />',
#  '<meta property="og:image" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png"/>',
#  '<meta property="article:publisher" content="https://www.facebook.com/Reuters" />',
#  '',
#  '<script type="application/ld+json">',
#  '    {',
#  '        "@context": "http://schema.org",',
#  '        "@type": "WebPage",',
#  '        "headline": "Breaking News, Top News & Latest News Headlines | Reuters",',
#  '        "url": "http://www.reuters.com/news/archive/worldNews",',
#  '        "thumbnailUrl": "",',
#  '        "dateCreated": "",',
#  '        "description": "Get the latest breaking news and top news headlines at Reuters.com",',
#  '        "publisher": "Reuters",',
#  '        "creator": [],',
#  '        "keywords": ["top news","breaking news","latest news","news headlines","World"]',
#  '    }',
#  '</script>',
#  '<meta name="DCSext.rChannel" content="Article - News"> ',
#  '',
#  '<meta name="DCSext.ContentChannel"  content="Default">',
#  '<meta name="DCSext.ContentType"  content="Archive">',
#  '<meta name="DCSext.DartZone" content="us.reuters/world/article_archive" />',
#  '<meta name="WT.cg_n" content="World">',
#  '<meta name="WT.cg_s" content="World">',
#  '<link rel="shortcut icon" type="image/x-icon" href="//s3.reutersmedia.net/resources_v2/images/favicon/favicon.ico" />',
#  '<link rel="icon" type="image/png" href="//s3.reutersmedia.net/resources_v2/images/favicon/favicon-16x16.png" sizes="16x16" />',
#  '<link rel="icon" type="image/png" href="//s1.reutersmedia.net/resources_v2/images/favicon/favicon-32x32.png" sizes="32x32" />',
#  '<link rel="icon" type="image/png" href="//s3.reutersmedia.net/resources_v2/images/favicon/favicon-96x96.png" sizes="96x96" />',
#  '<link rel="stylesheet" type="text/css" href="//s2.reutersmedia.net/resources_v2/css/core.css" />',
#  '<link rel="stylesheet" type="text/css" href="//s4.reutersmedia.net/resources_v2/css/core-modules.css" />',
#  '    <script src="//s3.reutersmedia.net/resources_v2/js/libraries/jquery-2.2.4.min.js" type="text/javascript"></script>',
#  '',
#  '<style>',
#  '.column2 .module {',
#  '    display: inline-block;',
#  '    width: 100%;',
#  '    margin: 0 0 20px 0;',
#  '}',
#  '',
#  '.column2 .module .moduleHeader {',
#  '    margin: 0;',
#  '}',
#  '',
#  '.column2 .module .moduleHeader {',
#  '    background: #333;',
#  '    padding: 8px 0;',
#  '}',
#  '',
#  '.column2 .module .moduleHeader h3 {',
#  '    font-size: 16px;',
#  '    font-weight: bold;',
#  '    text-transform: uppercase;',
#  '    margin: 0 10px;',
#  '    padding: 0;',
#  '    color: #FFF;',
#  '    text-align: left;',
#  '}',
#  '',
#  '.column2 .module .moduleHeader h3 a {',
#  '    color: #FFF;',
#  '}',
#  '',
#  '.column2 .module .moduleBody {',
#  '    padding-top: 8px;',
#  '}',
#  '',
#  '.column2 .module .moduleBody h2 {',
#  '    font-family: knowledge, helvetica, arial, sans-serif;',
#  '    font-weight: 500;',
#  '    font-size: 1.8em;',
#  '    line-height: 20px;',
#  '}',
#  '',
#  '.column2 .module .moduleBody .feature .photo {',
#  '    float: left;',
#  '    margin: 0 8px 8px 0;',
#  '}',
#  '',
#  '.column2 .module .moduleBody ul {',
#  '    list-style: none;',
#  '    padding-left: 15px;',
#  '    margin-bottom: 18px;',
#  '}',
#  '',
#  '.column2 .module .moduleBody li {',
#  '    padding-bottom: 8px;',
#  '    list-style: none;',
#  '    font-family: knowledge, helvetica, arial, sans-serif;',
#  '    font-weight: 500;',
#  '    font-size: 1.4em;',
#  '    line-height: 18px;',
#  '}',
#  '',
#  '.column2 .module .moduleBody li:before {',
#  '    color: #ff8000;',
#  '    content: "\\2022";',
#  '    font-size: 1.5em;',
#  '    margin-left: -15px;',
#  '    padding-right: 5px;',
#  '    vertical-align: top;',
#  '}',
#  '',
#  '.column2 .module .moduleBody li .info {',
#  '    display: inline-block;',
#  '}',
#  '',
#  '.column2 .module .moreLink {',
#  '    text-align: right;',
#  '    font-size: 1.2em;',
#  '}',
#  '</style><script src="//s2.reutersmedia.net/resources_v2/js/libraries/cookie.js" type="text/javascript"></script>',
#  '<script src="//s2.reutersmedia.net/resources_v2/js/core.js" type="text/javascript"></script>',
#  '<script src="//s2.reutersmedia.net/resources_v2/js/search.js" type="text/javascript"></script>',
#  "<script type='text/javascript'>",
#  '        var _sf_async_config = _sf_async_config || {};',
#  '        _sf_async_config.uid = 52639; ',
#  "        _sf_async_config.domain = 'reuters.com';  ",
#  "        _sf_async_config.topStorageDomain = 'reuters.com'; ",
#  '        _sf_async_config.path = document.querySelector("link[rel=\'canonical\']").getAttribute("href").replace(\'http://www.\', \'\'); ',
#  '        _sf_async_config.flickerControl = false;',
#  '        var _sf_startpt = (new Date()).getTime();',
#  "    </script><script async src='//static.chartbeat.com/js/chartbeat_mab.js'></script></head>",
#  '<body class="BETAUS archive">',
#  '    <!-- New Google Tag Manager (noscript) -->',
#  '         <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-W9SLGS"',
#  '        height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript> ',
#  '    <!-- End Google Tag Manager (noscript) -->',
#  '',
#  '',
#  '',
#  '',
#  '<section id="breakingNewsContainer" class="hidden"><div id="breakingNews" class="group wrap"><div class="breaking-content"><div class="breaking-news-type"></div><div class="breaking-news-content"></div></div><div class="close-btn">X</div></div></section>',
#  '',
#  '    <header id="headerMain">',
#  '        <div class="container group">',
#  '            <div class="edition-container group">',
#  '                <div class="edition-label">Edition:</div>',
#  '                <div class="edition-selector">',
#  '                    <div class="edition">United States</div>',
#  '                    <div class="edition-arrow"></div>',
#  '                </div>',
#  '            </div>',
#  '            <div class="reuters-nav-main">',
#  '                <h2 class="reuters-logo">',
#  '                    <a href="/" title="Reuters"></a>',
#  '                </h2>',
#  '            </div>',
#  '            <div id="utilities" class="utilities"></div>',
#  '        </div>',
#  '    </header>',
#  '    <nav id="headerNav">',
#  '        <div class="container group">',
#  '            <div class="header-mini-logo">',
#  '                    <a href="/" title="Reuters"></a>',
#  '            </div>',
#  '            <ul class="horizontal-list nav-list">',
#  '                <li class="nav-item home-tab active-icon',
#  '                                                no-subnav" id="nav-item-1">',
#  '                                            <a href="/home" class="nav-link-sec">',
#  '                                                <div class="home-icon"></div>',
#  '                                                <span class="text"></span>',
#  '                                            </a>',
#  '                                        </li>',
#  '                <li class="nav-item" id="nav-item-2">',
#  '                                       <a href="/finance" class="nav-link-sec">Business</a>',
#  '                                <div class="subnav" id="subnav-2">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/finance" class="nav-link-subsec">Business Home</a></li>',
#  '                                        <li><a href="/legal" class="nav-link-subsec">Legal</a></li>',
#  '                                        <li><a href="/finance/deals" class="nav-link-subsec">Deals</a></li>',
#  '                                        <li><a href="/subjects/aerospace-and-defense" class="nav-link-subsec">Aerospace & Defense</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/subjects/banks" class="nav-link-subsec">Finance</a></li>',
#  '                                        <li><a href="/subjects/autos" class="nav-link-subsec">Autos</a></li>',
#  '                                        <li><a href="/finance/summits" class="nav-link-subsec">Reuters Summits</a></li>',
#  '                                        <li><a href="/news/subjects/ADventures" class="nav-link-subsec">ADventures</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/data-dive" class="nav-link-subsec">Data Dive</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-3">',
#  '                                       <a href="/finance/markets" class="nav-link-sec">Markets</a>',
#  '                                <div class="subnav" id="subnav-3">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/finance/markets" class="nav-link-subsec">Markets Home</a></li>',
#  '                                        <li><a href="/finance/markets/us" class="nav-link-subsec">U.S. Markets</a></li>',
#  '                                        <li><a href="/finance/markets/europe" class="nav-link-subsec">European Markets</a></li>',
#  '                                        <li><a href="/finance/markets/asia" class="nav-link-subsec">Asian Markets</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/finance/global-market-data" class="nav-link-subsec">Global Market Data</a></li>',
#  '                                        <li><a href="/finance/markets/indices" class="nav-link-subsec">Stocks</a></li>',
#  '                                        <li><a href="/finance/bonds" class="nav-link-subsec">Bonds</a></li>',
#  '                                        <li><a href="/finance/currencies" class="nav-link-subsec">Currencies</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/finance/commodities" class="nav-link-subsec">Commodities</a></li>',
#  '                                        <li><a href="/finance/futures" class="nav-link-subsec">Futures</a></li>',
#  '                                        <li><a href="/finance/funds" class="nav-link-subsec">Funds</a></li>',
#  '                                        <li><a href="/finance/EarningsUS" class="nav-link-subsec">Earnings</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/finance/markets/dividends" class="nav-link-subsec">Dividends</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-4">',
#  '                                       <a href="/news/world" class="nav-link-sec">World</a>',
#  '                                <div class="subnav" id="subnav-4">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/news/world" class="nav-link-subsec">World Home</a></li>',
#  '                                        <li><a href="/news/us" class="nav-link-subsec">U.S.</a></li>',
#  '                                        <li><a href="/subjects/specialReports" class="nav-link-subsec">Special Reports</a></li>',
#  '                                        <li><a href="http://www.reuters.com/investigates/" class="nav-link-subsec">Reuters Investigates</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/subjects/euro-zone" class="nav-link-subsec">Euro Zone</a></li>',
#  '                                        <li><a href="/subjects/middle-east" class="nav-link-subsec">Middle East</a></li>',
#  '                                        <li><a href="/places/china" class="nav-link-subsec">China</a></li>',
#  '                                        <li><a href="/places/japan" class="nav-link-subsec">Japan</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/places/mexico" class="nav-link-subsec">Mexico</a></li>',
#  '                                        <li><a href="/places/brazil" class="nav-link-subsec">Brazil</a></li>',
#  '                                        <li><a href="/places/africa" class="nav-link-subsec">Africa</a></li>',
#  '                                        <li><a href="/places/russia" class="nav-link-subsec">Russia</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/places/india" class="nav-link-subsec">India</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-5">',
#  '                                       <a href="/politics" class="nav-link-sec">Politics</a>',
#  '                                <div class="subnav" id="subnav-5">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/politics" class="nav-link-subsec">Politics Home</a></li>',
#  '                                        <li><a href="http://polling.reuters.com" class="nav-link-subsec">Polling Explorer</a></li>',
#  '                                        <li><a href="http://live.reuters.com/Event/Live_US_Politics" class="nav-link-subsec">Live: U.S. Politics</a></li>',
#  '                                        <li><a href="/subjects/supreme-court" class="nav-link-subsec">Supreme Court</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-6">',
#  '                                       <a href="/news/technology" class="nav-link-sec">Tech</a>',
#  '                                <div class="subnav" id="subnav-6">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/news/technology" class="nav-link-subsec">Technology Home</a></li>',
#  '                                        <li><a href="/news/science" class="nav-link-subsec">Science</a></li>',
#  '                                        <li><a href="/bizfinance/technology/Top100Innovators" class="nav-link-subsec">Top 100 Global Innovators</a></li>',
#  '                                        <li><a href="/news/media" class="nav-link-subsec">Media</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/news/environment" class="nav-link-subsec">Environment</a></li>',
#  '                                        <li><a href="/innovation" class="nav-link-subsec">Innovation</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-7">',
#  '                                       <a href="/commentary" class="nav-link-sec">Commentary</a>',
#  '                                <div class="subnav" id="subnav-7">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/commentary" class="nav-link-subsec">Commentary Home </a></li>',
#  '                                        <li><a href="/tools/podcasts/" class="nav-link-subsec">Podcasts</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-8">',
#  '                                       <a href="/breakingviews" class="nav-link-sec">Breakingviews</a>',
#  '                                <div class="subnav" id="subnav-8">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/breakingviews" class="nav-link-subsec">Breakingviews Home</a></li>',
#  '                                        <li><a href="/video/breakingviews" class="nav-link-subsec">Breakingviews Video</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-9">',
#  '                                       <a href="/finance/personal-finance" class="nav-link-sec">Money</a>',
#  '                                <div class="subnav" id="subnav-9">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/finance/personal-finance" class="nav-link-subsec">Money Home</a></li>',
#  '                                        <li><a href="/finance/personal-finance/retirement" class="nav-link-subsec">Retirement</a></li>',
#  '                                        <li><a href="/subjects/us-lipper-awards" class="nav-link-subsec">Lipper Awards</a></li>',
#  '                                        <li><a href="/finance/personal-finance/analyst-research" class="nav-link-subsec">Analyst Research</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="http://stockscreener.us.reuters.com/Stock/US/Index?quickscreen=gaarp" class="nav-link-subsec">Stock Screener</a></li>',
#  '                                        <li><a href="http://funds.us.reuters.com/US/screener/screener.asp" class="nav-link-subsec">Fund Screener</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item" id="nav-item-10">',
#  '                                       <a href="/news/lifestyle" class="nav-link-sec">Life</a>',
#  '                                <div class="subnav" id="subnav-10">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/news/health" class="nav-link-subsec">Health</a></li>',
#  '                                        <li><a href="/news/sports" class="nav-link-subsec">Sports</a></li>',
#  '                                        <li><a href="/news/entertainment/arts" class="nav-link-subsec">Arts</a></li>',
#  '                                        <li><a href="/news/entertainment" class="nav-link-subsec">Entertainment</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        <li><a href="/news/oddlyEnough" class="nav-link-subsec">Oddly Enough</a></li>',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item pictures-tab active-icon active-text',
#  '                                               " id="nav-item-11">',
#  '                                            <a href="/news/pictures" class="nav-link-sec">',
#  '                                                <div class="pictures-icon"></div>',
#  '                                                <span class="text">Pictures</span>',
#  '                                            </a>',
#  '                                        <div class="subnav" id="subnav-11">',
#  '                            <div class="subnav-inset">',
#  '                                <ul class="subnav-list">',
#  '                                    <li><a href="/news/pictures" class="nav-link-subsec">Pictures Home</a></li>',
#  '                                        <li><a href="http://widerimage.reuters.com" class="nav-link-subsec">The Wider Image</a></li>',
#  '                                        <li><a href="http://widerimage.reuters.com/photographer" class="nav-link-subsec">Photographers</a></li>',
#  '                                        <li><a href="/focus-360/" class="nav-link-subsec">Focus 360</a></li>',
#  '                                        </ul>',
#  '                                            <ul class="subnav-list">',
#  '                                        </ul>',
#  '                            </div>',
#  '                        </div>',
#  '                    </li>',
#  '                <li class="nav-item video-tab active-icon active-text',
#  '                                                no-subnav" id="nav-item-12">',
#  '                                            <a href="/video" class="nav-link-sec">',
#  '                                                <div class="video-icon"></div>',
#  '                                                <span class="text">Video</span>',
#  '                                            </a>',
#  '                                        </li>',
#  '                <li class="nav-item search-tab active-icon no-subnav"><div class="search-icon"></div></li>',
#  '            </ul>',
#  '            <div id="searchBar">',
#  '                <form id="searchForm" class="search-form" name="searchbox" method="get" action="/search/news" autocomplete="off">',
#  '                    <input id="searchfield" class="search-field" name="blob" type="text" value="" onfocus="this.value = this.value;"  size="30" maxlength="128">',
#  '                    <span class="search-line"></span>',
#  '                    <input type="submit" id="search-submit-button" class="search-submit-button" value="" onmousedown="if(document.forms[\'searchbox\'].blob.value == \'Search Reuters\') { document.forms[\'searchbox\'].blob.value = \'\'; }">',
#  '                    <div class="search-close-button"></div>',
#  '                </form>',
#  '            </div>',
#  '            </div>',
#  '    </nav>',
#  '    <div class="nav-white-space"></div>',
#  '    <div class="edition-header">',
#  '        <div class="container">',
#  '            <div class="selection-header"></div>',
#  '            <ul class="edition-list">',
#  '                <li>',
#  '                    <div class="item"><a href="//af.reuters.com">Africa</a></div>',
#  '                    <div class="item"><a href="//lta.reuters.com">América Latina</a></div>',
#  '                </li>',
#  '                <li>',
#  '                    <div class="item"><a href="//ara.reuters.com">عربي</a></div>',
#  '                    <div class="item"><a href="//ar.reuters.com">Argentina</a></div>',
#  '                </li>',
#  '                <li>',
#  '                    <div class="item"><a href="//br.reuters.com">Brasil</a></div>',
#  '                    <div class="item"><a href="//ca.reuters.com">Canada</a></div>',
#  '                </li>   ',
#  '                <li>',
#  '                    <div class="item"><a href="//cn.reuters.com" class="">中国</a></div>',
#  '                    <div class="item"><a href="//de.reuters.com" class="">Deutschland</a></div>',
#  '                </li>',
#  '                <li>',
#  '                    <div class="item"><a href="//es.reuters.com">España</a></div>',
#  '                    <div class="item"><a href="//fr.reuters.com">France</a></div>',
#  '                </li>',
#  '                <li>',
#  '                    <div class="item"><a href="//in.reuters.com" class="">India</a></div>',
#  '                    <div class="item"><a href="//it.reuters.com">Italia</a></div>',
#  '                </li>',
#  '                <li>',
#  '                    <div class="item"><a href="//jp.reuters.com" class="">日本</a></div>',
#  '                    <div class="item"><a href="//mx.reuters.com">México</a></div>',
#  '                </li>',
#  '                <li>',
#  '                    <div class="item"><a href="//ru.reuters.com">РОССИЯ</a></div>',
#  '                    <div class="item"><a href="//uk.reuters.com" class="">United Kingdom</a></div>',
#  '                </li> ',
#  '                <li><div class="item"><a href="//www.reuters.com" class="active">United States</a></div></li>',
#  '            </ul>',
#  '        </div>',
#  '    </div>',
#  '    ',
#  '    <div id="content">',
#  '            <div id="overlayForSearch"></div><section class="ad-horizontal">',
#  '<div class="group wrap" id="bannerStrip">',
#  '<div id="div_gpt_lb" class="ad-leaderboard"><script>',
#  "gatherAd('div_gpt_lb', [[728, 90],[970,250],[970,180],[970,90],[1,1]], TR3.extractDartZone(), 'yes', 'leaderboard');",
#  '</script></div>',
#  '',
#  '<div class="linebreak"></div>',
#  '</div>',
#  '</section><section>',
#  '<div class="group wrap" id="">',
#  '<div class="column1 col col-10">',
#  '<div id="sectionTitle"><header class="module-header ">',
#  '                        <h4 class="module-heading">',
#  '                                    World News <span class="title-last">Headlines</span>',
#  '                                    </h4>',
#  '                            </header>',
#  '                </div><section  class="module  ">',
#  '',
#  '<section class="module-content">',
#  '<div class="news-headline-list medium">',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-usa-navy-asia-idUSKBN1972SW">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s2.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189403538&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G08D"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-usa-navy-asia-idUSKBN1972SW">',
#  '<h3 class="story-title">',
#  'Seven sailors missing after U.S. Navy destroyer collides with container ship off Japan</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  '        <p>Search and rescue efforts went on after dark for seven U.S. sailors missing after the U.S. Navy destroyer USS Fitzgerald collided with a Philippine-flagged container ship more than three times its size off eastern Japan early on Saturday.</p>',
#  '<time class="article-time">',
#  '<span class="timestamp">9:27am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-russia-usa-sanctions-idUSKBN1980CF">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s4.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189402655&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G07W"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-russia-usa-sanctions-idUSKBN1980CF">',
#  '<h3 class="story-title">',
#  'Putin: more U.S. sanctions would be harmful, talk of retaliation premature</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  '        <p>Russian President Vladimir Putin said new sanctions under consideration by the United States would damage relations between the two countries, but it was too early to talk about retaliation, state news agency RIA reported on Saturday.</p>',
#  '<time class="article-time">',
#  '<span class="timestamp">7:14am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo  ">',
#  '<a href="/article/us-afghanistan-attack-idUSKBN1980HJ">',
#  '<img class="placeholder-image" src="//s1.reutersmedia.net/resources_v2/images/1x1.png" border="0" alt="" />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-afghanistan-attack-idUSKBN1980HJ">',
#  '<h3 class="story-title">',
#  'Four U.S. soldiers killed in apparent insider attack in Afghanistan: official</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  '        <p>At least four American soldiers were shot and killed in an apparent insider attack by an Afghan soldier at a base in northern Afghanistan on Saturday, a military official said.</p>',
#  '<time class="article-time">',
#  '<span class="timestamp">9:10am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-yemen-security-hodeidah-idUSKBN1980G0">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s2.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189409676&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0C4"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-yemen-security-hodeidah-idUSKBN1980G0">',
#  '<h3 class="story-title">',
#  'Yemen government agrees to U.N. Hodeidah plan, Houthis skeptical</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  "        <p>Yemen's Saudi-backed government said on Saturday it agreed to a two-point plan advanced by the United Nations to ease suffering in the country's civil war, but the Iran-aligned Houthi movement remained skeptical.</p>",
#  '<time class="article-time">',
#  '<span class="timestamp">8:38am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-pope-merkel-idUSKBN1980HW">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s1.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189411965&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0D2"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-pope-merkel-idUSKBN1980HW">',
#  '<h3 class="story-title">',
#  'Pope tells Merkel to keep pressing for international cooperation</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  "        <p>Pope Francis has asked Germany to keep fighting for the Paris climate change deal and to 'tear down walls' that inhibit international cooperation, Chancellor Angela Merkel said on Saturday, offering a stark contrast between her agenda and U.S. policy.</p>",
#  '<time class="article-time">',
#  '<span class="timestamp">9:25am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-philippines-militants-idUSKBN1980EE">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s1.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189407317&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0B0"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-philippines-militants-idUSKBN1980EE">',
#  '<h3 class="story-title">',
#  'Duterte resurfaces after rest, says battle with militants winding down</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  '        <p>President Rodrigo Duterte of the Philippines, who had avoided public appearances for nearly a week to recover from what spokesmen described as fatigue, said on Saturday that a battle with Islamist militants in Marawi City was winding down, but the insurgency had deep roots.</p>',
#  '<time class="article-time">',
#  '<span class="timestamp">7:55am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-mideast-crisis-syria-un-idUSKBN1980DP">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s2.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189406084&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0AE"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-mideast-crisis-syria-un-idUSKBN1980DP">',
#  '<h3 class="story-title">',
#  'U.N. mediator targets fresh Syria talks for July 10</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  '        <p>The United Nations special mediator for Syria, Staffan de Mistura, wants to start a fresh round of talks between Syrian factions on July 10, his office said on Saturday.</p>',
#  '<time class="article-time">',
#  '<span class="timestamp">8:51am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo  ">',
#  '<a href="/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y">',
#  '<img class="placeholder-image" src="//s1.reutersmedia.net/resources_v2/images/1x1.png" border="0" alt="" />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y">',
#  '<h3 class="story-title">',
#  'Iraqi forces remove Islamic State fighters from vicinity of U.S.base in Syria</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  '        <p>The Iraqi army and Sunni tribal fighters have dislodged Islamic State from the al-Waleed border crossing into Syria, an Iraqi military statement said on Saturday.</p>',
#  '<time class="article-time">',
#  '<span class="timestamp">9:05am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-egypt-court-idUSKBN198096">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s4.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189405089&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G09T"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-egypt-court-idUSKBN198096">',
#  '<h3 class="story-title">',
#  'Egyptian court recommends death penalty for 30 over assassination of prosecutor</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  "        <p>A Cairo criminal court on Saturday recommended the death penalty for 30 people convicted of involvement in the 2015 assassination of Egypt's top prosecutor, the most senior state official killed by militants in recent years.</p>",
#  '<time class="article-time">',
#  '<span class="timestamp">7:20am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '<article class="story ">',
#  '<div class="story-photo lazy-photo ">',
#  '<a href="/article/us-britain-fire-idUSKBN1980CY">',
#  '<img',
#  '                                ',
#  'src="//s1.reutersmedia.net/resources_v2/images/1x1.png"',
#  'org-src="https://s3.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189406546&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0AK"',
#  '                                ',
#  '                                border="0" alt=""',
#  '                                 />',
#  '</a>',
#  '</div>',
#  '<div class="story-content">',
#  '<a href="/article/us-britain-fire-idUSKBN1980CY">',
#  '<h3 class="story-title">',
#  'British PM May tries to quell public anger after deadly London fire</h3>',
#  '</a>',
#  '        <div class="contributor"></div>',
#  "        <p>British Prime Minister Theresa May's government sought on Saturday to quell anger over a deadly tower block fire by pledging to support the victims of the blaze after protesters jeered her when she visited local residents.</p>",
#  '<time class="article-time">',
#  '<span class="timestamp">9:35am EDT</span>',
#  '</time>',
#  '</div>',
#  '',
#  '</article>',
#  '</div>',
#  '</section>',
#  '</section>',
#  '',
#  '<div class="control-nav" data-page=\'1\' data-page-size="10" data-type=\'\' data-more=\'false\'>',
#  '    <span class="control-nav-prev control-nav-disabled"></span>',
#  '        <span class="control-nav-next control-nav-disabled">Earlier</span>',
#  '        </div>',
#  '',
#  '',
#  '<div class="linebreak"></div>',
#  '</div>',
#  '',
#  '<div class="column2 col col-4">',
#  '<div class="module">',
#  '',
#  '<div class="moduleHeader">',
#  '<h3>',
#  '<a href="/news/video?videoChannel=1003" >',
#  'Politics Video</a>',
#  '</h3>',
#  '</div>',
#  '<div class="moduleBody">',
#  '<div class="mediaList videoList size300">',
#  '<div class="feature"><div class="photo">',
#  '                 <a href="/news/video/story?videoId=371909343&videoChannel=1003"  >                ',
#  '                  <div class="videoOverlay"></div>',
#  '                  <img',
#  '                                ',
#  '                                        src="https://s3.reutersmedia.net/resources/r/?d=20170616&i=129819935&w=300&r=129819935-1&t=2"',
#  '                                ',
#  '                                border="0" alt="Trump orders clampdown on Cuba travel and trade"',
#  '                                 />',
#  '</a>',
#  '</div><h2><a href="/news/video/story?videoId=371909343&videoChannel=1003"  >Trump orders clampdown on Cuba travel and trade</a>',
#  '</h2></div><ul><li><div class="info"><a href="/news/video/story?videoId=371909293&videoChannel=1003"  >Scalise showing improvement after being shot: lead surgeon</a>',
#  '</div><div class="linebreak"></div></li><li><div class="info"><a href="/news/video/story?videoId=371909058&videoChannel=1003"  >Trump clamps down on Cuba travel</a>',
#  '</div><div class="linebreak"></div></li><li><div class="info"><a href="/news/video/story?videoId=371907943&videoChannel=1003"  >What happened to Warmbier a "truly terrible thing": Trump</a>',
#  '</div><div class="linebreak"></div></li></ul></div><!-- end mediaList -->',
#  '<div class="moreLink">',
#  '<a href="/news/video?videoChannel=1003">&#187; More Politics Video</a></div></div>',
#  '</div>',
#  '',
#  '',
#  '<div id="div_gpt_mpu"><script>',
#  "gatherAd('div_gpt_mpu', [[300, 250],[300,600],[300,1050]], TR3.extractDartZone(), 'yes', 'mpu');",
#  '</script></div><div class="linebreak"></div>',
#  '',
#  '',
#  '<div class="module">',
#  '',
#  '<div class="moduleHeader">',
#  '<h3>',
#  '<a href="http://www.reuters.com/politics" >',
#  'Politics News</a>',
#  '</h3>',
#  '</div>',
#  '<div class="moduleBody">',
#  '<div class="feature"><div class="photo">',
#  '<a href="/article/us-usa-cuba-idUSKBN1970EC"  ><img',
#  '                                ',
#  '                                        src="https://s3.reutersmedia.net/resources/r/?m=02&d=20170616&t=2&i=1189335626&w=300&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5F1UQ"',
#  '                                ',
#  '                                border="0" alt="Photo"',
#  '                                 /></a>',
#  '</div><h2><a href="/article/us-usa-cuba-idUSKBN1970EC"  >Trump rolls back parts of what he calls \'terrible\' Obama Cuba policy</a>',
#  '</h2><p>MIAMI President Donald Trump on Friday ordered tighter restrictions on Americans traveling to Cuba and a clampdown on U.S. business dealings with the Caribbean island’s military, saying he was canceling former President Barack Obama\'s "terrible and misguided deal" with Havana. |&nbsp;<span class="inlineLinks"><a href="/video/2017/06/16/trump-clamps-down-on-cuba-travel?videoId=371909058&newsChannel=politicsNews"  >Video</a>',
#  '</span></p>',
#  '</div><ul>',
#  '<li><a href="/article/us-usa-trump-ethics-idUSKBN1972XM"  >Trump owes lenders at least $315 million, disclosure shows</a>',
#  '</li><li><a href="/article/us-usa-trump-russia-ukraine-idUSKBN1971TT"  >Trump acknowledges he is under investigation in Russia probe</a>',
#  '</li><li><a href="/article/us-usa-trump-russia-lawyer-idUSKBN19800X"  >Trump adds Washington lawyer John Dowd to his legal team</a>',
#  '</li></ul>',
#  '<div class="moreLink">',
#  '<a href="http://www.reuters.com/politics">&#187; More</a></div></div>',
#  '</div>',
#  '<script>',
#  "var topStoryGrid = $('#topStory').find('.grid8');",
#  "if (topStoryGrid.hasClass('grid8')) {",
#  "    if ($('#latestHeadlines')) {",
#  "        $('#latestHeadlines').remove();",
#  '    }',
#  '};',
#  '</script>',
#  '',
#  '',
#  '<div id="div_gpt_mpulow"><script>',
#  "gatherAd('div_gpt_mpulow', [[300, 250],[300,600],[300,1050]], TR3.extractDartZone(), 'yes', 'mpulow');",
#  '</script></div>',
#  '',
#  '</div>',
#  '',
#  '</div>',
#  '</section><section class="ad-horizontal">',
#  '<div class="group wrap" id="">',
#  '<div id="div_gpt_lb_center" class="ad-leaderboard"><script>',
#  "gatherAd('div_gpt_lb_center', [[728, 90],[970,250],[970,180],[970,90],[970,66],[1,1]], TR3.extractDartZone(), 'yes', 'leaderboardcenter');",
#  '</script></div>',
#  '',
#  '<div class="linebreak"></div>',
#  '</div>',
#  '</section></div>',
#  '<footer>',
#  '<section class="footer">',
#  '<div class="group wrap" id="">',
#  '<script>',
#  '',
#  'callAds();',
#  '</script>',
#  '<div id="section-follow-buttons"><span class="footer-follow">Follow Reuters: </span>',
#  '<ul>',
#  '    <li id="foot-twitter"><a href="//www.twitter.com/reuters" target="_blank"><span class="follow-button follow-twitter">Follow Us On Twitter</span></a></li>',
#  '    <li id="foot-facebook"><a href="//www.facebook.com/Reuters" target="_blank"><span class="follow-button follow-facebook">Follow Us On Facebook</span></a></li>',
#  '    <li id="foot-rssfeed"><a href="//www.reuters.com/tools/rss" target="_blank"><span class="follow-button follow-rss">Follow Us On RSS</span></a></li>',
#  '    <li id="foot-instagram"><a href=" //instagram.com/reuters/" target="_blank"><span class="follow-button follow-instagram">Follow Us On Instagram</span></a></li>',
#  '    <li id="foot-youtube"><a href="//www.youtube.com/user/ReutersVideo" target="_blank"><span class="follow-button follow-youtube">Follow Us On YouTube</span></a></li>',
#  '    <li id="foot-linkedin"><a href="//www.linkedin.com/company/thomson-reuters_1400" target="_blank"><span class="follow-button follow-linkedin">Follow Us On LinkedIn</span></a></li>',
#  '</ul></div><div class="footer-more-links"><span class="footer-more">Subscribe: </span>',
#  '<a href="//www.reuters.com/tools/rss">Feeds</a> | <a href="//newslink.reuters.com/join/subscribe">Newsletters</a> | <a href="/tools/podcasts">Podcasts</a> | <a href="/tools/mobile">Apps</a> </div></div>',
#  '</section><section class="footer-body">',
#  '<div class="group wrap" id="">',
#  '<div class="footer-services-link"><a href="//agency.reuters.com" target="_blank">Reuters News Agency</a> | <a href="//agency.reuters.com/en/platforms-delivery/reuters-brand-attribution-guidelines.html" target="_blank">Brand Attribution Guidelines</a>  | <a href="//thomsonreuters.com/en/careers.html" target="_blank">Careers</a></div><div class="disclaimer"><div class="footer-summary">',
#  '<p>Reuters is the news and media division of <a href="//thomsonreuters.com/" target="_blank">Thomson Reuters</a>. Thomson Reuters is the world\'s largest international multimedia news agency, providing investing news, world news, business news, technology news, headline news, small business news, news alerts, personal finance, stock market, and mutual funds information available on Reuters.com, video, mobile, and interactive television platforms. Learn more about Thomson Reuters products:</p>',
#  '</div></div><div class="product-container">',
#  '  <a href="//financial.thomsonreuters.com/en/products/tools-applications/trading-investment-tools/eikon-trading-software.html" target="_blank">',
#  '    <div class="product">',
#  '      <div class="prod-title">Eikon</div>',
#  '        <div class="prod-content">Information, analytics and exclusive news on financial markets - delivered in an intuitive desktop and mobile interface ',
#  '        </div>',
#  '    </div>',
#  '  </a>',
#  '  <a href="//financial.thomsonreuters.com/en/products/infrastructure/trading-infrastructure/elektron-enterprise-data-management.html" target="_blank">  ',
#  '    <div class="product">',
#  '      <div class="prod-title">Elektron</div>',
#  '        <div class="prod-content">Everything you need to empower your workflow and enhance your enterprise data management ',
#  '      </div>',
#  '    </div>',
#  '  </a>',
#  '  <a href="//risk.thomsonreuters.com/products/world-check" target="_blank">  ',
#  '    <div class="product">',
#  '      <div class="prod-title">World-Check</div>',
#  '      <div class="prod-content">Screen for heightened risk individual and entities globally to help uncover hidden risks in business relationships and human networks ',
#  '      </div>',
#  '    </div>',
#  '  </a>  ',
#  '  <a href="//legalsolutions.thomsonreuters.com/law-products/westlaw-legal-research/" target="_blank">',
#  '    <div class="product">',
#  '      <div class="prod-title">Westlaw</div>',
#  '      <div class="prod-content">Build the strongest argument relying on authoritative content, attorney-editor expertise, and industry defining technology   ',
#  '      </div>',
#  '    </div>',
#  '  </a>',
#  '  <a href="//tax.thomsonreuters.com/products/brands/onesource/" target="_blank">  ',
#  '    <div class="product">',
#  '      <div class="prod-title">ONESOURCE</div>',
#  '      <div class="prod-content">The most comprehensive solution to manage all your complex and ever-expanding tax and compliance needs',
#  '      </div>',
#  '    </div>',
#  '  </a>',
#  '  <a href="//tax.thomsonreuters.com/products/brands/checkpoint/" target="_blank">  ',
#  '    <div class="product prod-last">',
#  '      <div class="prod-title">CHECKPOINT</div>',
#  '      <div class="prod-content">The industry leader for online information for tax, accounting and finance professionals ',
#  '      </div>',
#  '    </div>',
#  '  </a>  ',
#  '</div><div class="linebreak"></div>',
#  '<div class="footer-policy-links"><p> All quotes delayed a minimum of 15 minutes. <a href="/info/disclaimer">See here for a complete list</a> of exchanges and delays.</p>',
#  '<div class="footer-policies"><ul>',
#  '    ',
#  '<li class="h-links">',
#  '<div class="reuters-copyright"><script type="text/javascript">var year = new Date();document.write(\'<a href="//thomsonreuters.com/copyright/">&copy;  \' + year.getFullYear() + \' Reuters. All Rights Reserved.</a>\');</script></div>',
#  '</li>',
#  '<li class="h-links"><a href="//reuters.zendesk.com/" target="_blank">Site Feedback</a></li>',
#  '<li class="h-links"><a href="https://reuters.zendesk.com/anonymous_requests/new" target="_blank">Corrections</a></li>',
#  '<li class="h-links"><a href="/advertising-guidelines">Advertising Guidelines</a></li>',
#  '<li class="h-links"><a href="//info.evidon.com/pub_info/285" target="_blank">Cookies</a></li>',
#  '<li class="h-links"><a href="/terms-of-use">Terms of Use</a></li>',
#  '<li class="h-links h-links-last"><a href="/privacy-policy">Privacy Policy</a></li>',
#  '',
#  '</ul></div></div></div>',
#  '</section>',
#  '',
#  '</footer>',
#  '',
#  '<script src="//s4.reutersmedia.net/resources_v2/js/core-header.js" type="text/javascript"></script>',
#  '<script src="//s3.reutersmedia.net/resources_v2/js/core-login.js" type="text/javascript"></script>',
#  '<script src="//s2.reutersmedia.net/resources_v2/js/core-tracking.js" type="text/javascript"></script>',
#  '<script src="//s2.reutersmedia.net/resources_v2/js/rcom-social-share.js" type="text/javascript"></script>',
#  '    <script src="//s2.reutersmedia.net/resources_v2/js/libraries/core-lib.js" type="text/javascript"></script>',
#  '<script src="//s4.reutersmedia.net/resources_v2/js/core-modules.js" type="text/javascript"></script>',
#  '<script>',
#  ' if(window.location.href.indexOf("BigStory14") > -1 ){',
#  "$(document).prop('title', 'Rio 2016 Headlines');",
#  '//$("div#sectionTitle header").contents().filter(function(){ return this.nodeType == 1; }).filter(\':first\').text("RIO 2016").append(\'<span class=title-last> Headlines</span>\');',
#  '',
#  '}',
#  '</script><script language="javascript" type="text/javascript" src="//www.reuters.com/reuters_gpt_bootstrap_footer.js"></script>',
#  '',
#  '<script type="text/javascript">',
#  '$(document).ready( function() {',
#  'var sclTracking = new rcom_scrollTracker("Archive");',
#  'if( inAppleMobileDevice() ) {document.addEventListener("scroll", sclTracking, false);} else {$(window).scroll( sclTracking );}',
#  '});',
#  '</script>',
#  '',
#  '<section>',
#  '<div class="group" id="">',
#  "<script type='text/javascript'>",
#  '        var _sf_startpt = (new Date()).getTime();',
#  '        var _sf_async_config = _sf_async_config || {};',
#  '        ',
#  "        _sf_async_config.playerdomain = 'queso-cdn.prod.reuters.tv';",
#  "        _sf_async_config.sections = 'World'; ",
#  '        _sf_async_config.autoDetect = false;',
#  '        ',
#  "        _sf_async_config.authors = 'Reuters Editorial'; ",
#  "        _sf_async_config.type = 'Archive'; ",
#  '',
#  '        (function(){',
#  '          function loadChartbeat() {',
#  '            window._sf_endpt=(new Date()).getTime();',
#  "            var e = document.createElement('script');",
#  "            e.setAttribute('language', 'javascript');",
#  "            e.setAttribute('type', 'text/javascript');",
#  "            e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');",
#  '            document.body.appendChild(e);',
#  '          }',
#  '          var oldonload = window.onload;',
#  "          window.onload = (typeof window.onload != 'function') ?",
#  '             loadChartbeat : function() { oldonload(); loadChartbeat(); };',
#  '        })();',
#  '    </script>',
#  '</div>',
#  '</section>',
#  '',
#  '</body>',
#  '</html>']

# %% [markdown]
# ###### Extracting Titles

# %%
soup = BeautifulSoup(content, 'html.parser')
soup.find_all('h3', {'class':'story-title'})
# Out:
# [<h3 class="story-title">
#  								Seven sailors missing after U.S. Navy destroyer collides with container ship off Japan</h3>,
#  <h3 class="story-title">
#  								Putin: more U.S. sanctions would be harmful, talk of retaliation premature</h3>,
#  <h3 class="story-title">
#  								Four U.S. soldiers killed in apparent insider attack in Afghanistan: official</h3>,
#  <h3 class="story-title">
#  								Yemen government agrees to U.N. Hodeidah plan, Houthis skeptical</h3>,
#  <h3 class="story-title">
#  								Pope tells Merkel to keep pressing for international cooperation</h3>,
#  <h3 class="story-title">
#  								Duterte resurfaces after rest, says battle with militants winding down</h3>,
#  <h3 class="story-title">
#  								U.N. mediator targets fresh Syria talks for July 10</h3>,
#  <h3 class="story-title">
#  								Iraqi forces remove Islamic State fighters from vicinity of U.S.base in Syria</h3>,
#  <h3 class="story-title">
#  								Egyptian court recommends death penalty for 30 over assassination of prosecutor</h3>,
#  <h3 class="story-title">
#  								British PM May tries to quell public anger after deadly London fire</h3>]

# %%
titles = []
for title in soup.find_all('h3', {'class':'story-title'}):
    titles.append(title.string.strip())

# %%
titles
# Out:
# ['Seven sailors missing after U.S. Navy destroyer collides with container ship off Japan',
#  'Putin: more U.S. sanctions would be harmful, talk of retaliation premature',
#  'Four U.S. soldiers killed in apparent insider attack in Afghanistan: official',
#  'Yemen government agrees to U.N. Hodeidah plan, Houthis skeptical',
#  'Pope tells Merkel to keep pressing for international cooperation',
#  'Duterte resurfaces after rest, says battle with militants winding down',
#  'U.N. mediator targets fresh Syria talks for July 10',
#  'Iraqi forces remove Islamic State fighters from vicinity of U.S.base in Syria',
#  'Egyptian court recommends death penalty for 30 over assassination of prosecutor',
#  'British PM May tries to quell public anger after deadly London fire']

# %% [markdown]
# ###### Extracting first line of article

# %%
# there are some things in the p-tag that we don't need and they also cause errors when using string.strip method.
# Therefore, use try and except to avoid facing errors

first_lines = []
try:
    for first_line in soup.find_all('p'):
        first_lines.append(first_line.string.strip())
except:
    pass

# %%
first_lines
# Out:
# ['Search and rescue efforts went on after dark for seven U.S. sailors missing after the U.S. Navy destroyer USS Fitzgerald collided with a Philippine-flagged container ship more than three times its size off eastern Japan early on Saturday.',
#  'Russian President Vladimir Putin said new sanctions under consideration by the United States would damage relations between the two countries, but it was too early to talk about retaliation, state news agency RIA reported on Saturday.',
#  'At least four American soldiers were shot and killed in an apparent insider attack by an Afghan soldier at a base in northern Afghanistan on Saturday, a military official said.',
#  "Yemen's Saudi-backed government said on Saturday it agreed to a two-point plan advanced by the United Nations to ease suffering in the country's civil war, but the Iran-aligned Houthi movement remained skeptical.",
#  "Pope Francis has asked Germany to keep fighting for the Paris climate change deal and to 'tear down walls' that inhibit international cooperation, Chancellor Angela Merkel said on Saturday, offering a stark contrast between her agenda and U.S. policy.",
#  'President Rodrigo Duterte of the Philippines, who had avoided public appearances for nearly a week to recover from what spokesmen described as fatigue, said on Saturday that a battle with Islamist militants in Marawi City was winding down, but the insurgency had deep roots.',
#  'The United Nations special mediator for Syria, Staffan de Mistura, wants to start a fresh round of talks between Syrian factions on July 10, his office said on Saturday.',
#  'The Iraqi army and Sunni tribal fighters have dislodged Islamic State from the al-Waleed border crossing into Syria, an Iraqi military statement said on Saturday.',
#  "A Cairo criminal court on Saturday recommended the death penalty for 30 people convicted of involvement in the 2015 assassination of Egypt's top prosecutor, the most senior state official killed by militants in recent years.",
#  "British Prime Minister Theresa May's government sought on Saturday to quell anger over a deadly tower block fire by pledging to support the victims of the blaze after protesters jeered her when she visited local residents."]

# %% [markdown]
# ###### Extracting when the article was written

# %%
written_times = []
for written_time in soup.find_all('span', {'class':'timestamp'}):
    written_times.append(written_time.string.strip())

# %%
written_times
# Out:
# ['9:27am EDT',
#  '7:14am EDT',
#  '9:10am EDT',
#  '8:38am EDT',
#  '9:25am EDT',
#  '7:55am EDT',
#  '8:51am EDT',
#  '9:05am EDT',
#  '7:20am EDT',
#  '9:35am EDT']

# %% [markdown]
# ###### Extracting url link of article

# %%
url_links = []
import re

for tags in soup.find_all('a'):
    if re.search('article', tags['href']):
        url_links.append(tags['href'])

# %%
url_links
# Out:
# ['/article/us-usa-navy-asia-idUSKBN1972SW',
#  '/article/us-usa-navy-asia-idUSKBN1972SW',
#  '/article/us-russia-usa-sanctions-idUSKBN1980CF',
#  '/article/us-russia-usa-sanctions-idUSKBN1980CF',
#  '/article/us-afghanistan-attack-idUSKBN1980HJ',
#  '/article/us-afghanistan-attack-idUSKBN1980HJ',
#  '/article/us-yemen-security-hodeidah-idUSKBN1980G0',
#  '/article/us-yemen-security-hodeidah-idUSKBN1980G0',
#  '/article/us-pope-merkel-idUSKBN1980HW',
#  '/article/us-pope-merkel-idUSKBN1980HW',
#  '/article/us-philippines-militants-idUSKBN1980EE',
#  '/article/us-philippines-militants-idUSKBN1980EE',
#  '/article/us-mideast-crisis-syria-un-idUSKBN1980DP',
#  '/article/us-mideast-crisis-syria-un-idUSKBN1980DP',
#  '/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y',
#  '/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y',
#  '/article/us-egypt-court-idUSKBN198096',
#  '/article/us-egypt-court-idUSKBN198096',
#  '/article/us-britain-fire-idUSKBN1980CY',
#  '/article/us-britain-fire-idUSKBN1980CY',
#  '/article/us-usa-cuba-idUSKBN1970EC',
#  '/article/us-usa-cuba-idUSKBN1970EC',
#  '/article/us-usa-trump-ethics-idUSKBN1972XM',
#  '/article/us-usa-trump-russia-ukraine-idUSKBN1971TT',
#  '/article/us-usa-trump-russia-lawyer-idUSKBN19800X']

# %% [markdown]
# Since the last 5 urls are not headlines but just article links on the sidebar, we want to get rid of these

# %%
url_links = url_links[:-5]

# %%
url_links
# Out:
# ['/article/us-usa-navy-asia-idUSKBN1972SW',
#  '/article/us-usa-navy-asia-idUSKBN1972SW',
#  '/article/us-russia-usa-sanctions-idUSKBN1980CF',
#  '/article/us-russia-usa-sanctions-idUSKBN1980CF',
#  '/article/us-afghanistan-attack-idUSKBN1980HJ',
#  '/article/us-afghanistan-attack-idUSKBN1980HJ',
#  '/article/us-yemen-security-hodeidah-idUSKBN1980G0',
#  '/article/us-yemen-security-hodeidah-idUSKBN1980G0',
#  '/article/us-pope-merkel-idUSKBN1980HW',
#  '/article/us-pope-merkel-idUSKBN1980HW',
#  '/article/us-philippines-militants-idUSKBN1980EE',
#  '/article/us-philippines-militants-idUSKBN1980EE',
#  '/article/us-mideast-crisis-syria-un-idUSKBN1980DP',
#  '/article/us-mideast-crisis-syria-un-idUSKBN1980DP',
#  '/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y',
#  '/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y',
#  '/article/us-egypt-court-idUSKBN198096',
#  '/article/us-egypt-court-idUSKBN198096',
#  '/article/us-britain-fire-idUSKBN1980CY',
#  '/article/us-britain-fire-idUSKBN1980CY']

# %% [markdown]
# Since the url links have duplicates, we want to get rid of those. We can use set() but this will cause the order of the links to be shuffled

# %%
final_urls = []
for url in url_links:
    if url not in final_urls:
        final_urls.append(url)

# %%
final_urls
# Out:
# ['/article/us-usa-navy-asia-idUSKBN1972SW',
#  '/article/us-russia-usa-sanctions-idUSKBN1980CF',
#  '/article/us-afghanistan-attack-idUSKBN1980HJ',
#  '/article/us-yemen-security-hodeidah-idUSKBN1980G0',
#  '/article/us-pope-merkel-idUSKBN1980HW',
#  '/article/us-philippines-militants-idUSKBN1980EE',
#  '/article/us-mideast-crisis-syria-un-idUSKBN1980DP',
#  '/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y',
#  '/article/us-egypt-court-idUSKBN198096',
#  '/article/us-britain-fire-idUSKBN1980CY']

# %%
import pandas as pd

reuters_word_headlines = pd.DataFrame({'title':titles, 'headline content':first_lines, 'time':written_times,
                                     'link url':final_urls})

# %%
reuters_word_headlines=\
reuters_word_headlines.loc[:,('time', 'title', 'headline content', 'link url')]

# %%
# adding www.reuters.com in front of each url

reuters_word_headlines['link url'] =\
'www.reuters.com' + reuters_word_headlines['link url']

# %%
reuters_word_headlines
# Out:
#          time                                              title  \
# 0  9:27am EDT  Seven sailors missing after U.S. Navy destroye...
# 1  7:14am EDT  Putin: more U.S. sanctions would be harmful, t...
# 2  9:10am EDT  Four U.S. soldiers killed in apparent insider ...
# 3  8:38am EDT  Yemen government agrees to U.N. Hodeidah plan,...
# 4  9:25am EDT  Pope tells Merkel to keep pressing for interna...
# 5  7:55am EDT  Duterte resurfaces after rest, says battle wit...
# 6  8:51am EDT  U.N. mediator targets fresh Syria talks for Ju...
# 7  9:05am EDT  Iraqi forces remove Islamic State fighters fro...
# 8  7:20am EDT  Egyptian court recommends death penalty for 30...
# 9  9:35am EDT  British PM May tries to quell public anger aft...
#
#                                     headline content  \
# 0  Search and rescue efforts went on after dark f...
# 1  Russian President Vladimir Putin said new sanc...
# 2  At least four American soldiers were shot and ...
# 3  Yemen's Saudi-backed government said on Saturd...
# 4  Pope Francis has asked Germany to keep fightin...
# 5  President Rodrigo Duterte of the Philippines, ...
# 6  The United Nations special mediator for Syria,...
# 7  The Iraqi army and Sunni tribal fighters have ...
# 8  A Cairo criminal court on Saturday recommended...
# 9  British Prime Minister Theresa May's governmen...
#
#                                             link url
# 0  www.reuters.com/article/us-usa-navy-asia-idUSK...
# 1  www.reuters.com/article/us-russia-usa-sanction...
# 2  www.reuters.com/article/us-afghanistan-attack-...
# 3  www.reuters.com/article/us-yemen-security-hode...
# 4  www.reuters.com/article/us-pope-merkel-idUSKBN...
# 5  www.reuters.com/article/us-philippines-militan...
# 6  www.reuters.com/article/us-mideast-crisis-syri...
# 7  www.reuters.com/article/us-mideast-crisis-iraq...
# 8  www.reuters.com/article/us-egypt-court-idUSKBN...
# 9  www.reuters.com/article/us-britain-fire-idUSKB...

# %% [markdown]
# ### Method 2 : Using python urllib and BeautifulSoup

# %%
from urllib import request

url = 'http://www.reuters.com/news/archive/worldNews?view=page'

fhand = request.urlopen(url)
for line in fhand:
    print(line.strip().decode())
# Out:
# <!--[if !IE]> This has been served from cache <![endif]-->
# <!--[if !IE]> Request served from apache server: produs--i-070ae7cf4c5cf96cf <![endif]-->
# <!--[if !IE]> Cached on Sat, 17 Jun 2017 13:37:20 GMT and will expire on Sat, 17 Jun 2017 13:42:20 GMT <![endif]-->
# <!--[if !IE]> token: c45cf780-a819-4ecd-8663-3aef8ed92eb9 <![endif]-->
# <!--[if !IE]> Tomcat Server /produs--i-04d0ea63c73100166/ <![endif]-->
#
# <!--[if !IE]> App Server /produs--i-04d0ea63c73100166/ <![endif]-->
#
# <!doctype html><html lang="en"><head>
# <title>World News Headlines  | Reuters</title>
# <meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta http-equiv="x-dns-prefetch-control" content="on"><link rel="dns-prefetch" href="//s1.reutersmedia.net"/><link rel="dns-prefetch" href="//s2.reutersmedia.net"/><link rel="dns-prefetch" href="//s3.reutersmedia.net"/><link rel="dns-prefetch" href="//s4.reutersmedia.net"/><link rel="dns-prefetch" href="//static.reuters.com"/><link rel="dns-prefetch" href="//www.googletagservices.com"/><link rel="dns-prefetch" href="//www.googletagmanager.com"/><link rel="dns-prefetch" href="//www.google-analytics.com"/><link rel="dns-prefetch" href="//static.chartbeat.com"/><meta name="robots" content="INDEX, FOLLOW">
#
# <!-- Page hiding snippet  -->
# <style>.async-hide { opacity: 0 !important} </style>
# <script>
# (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);
# })(window,document.documentElement,'async-hide','dataLayer',2000,{'GTM-W9SLGS':true});
# </script>
#
# <!-- Data Layer Object Declaration -->
# <script>
# window.dataLayer = window.dataLayer || [];
# </script>
#
# <!-- New Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
# {'gtm.start': new Date().getTime(),event:'gtm.js'}
# );var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W9SLGS');</script>
# <!-- End Google Tag Manager -->
#
# <meta name="google-site-verification" content="SVDMcE-27ZUUuh-EcZzejAJ0YIFjxD9H_nwAX6YVTw4" /><meta name="msvalidate.01" content="2055F771212E9574BFD5AF29D47FBA04" /><script type="text/javascript" >
#
# // Rubicon Initialize
# (function() {
# var account_id = 11384;
# var rct = document.createElement('script');
# rct.type = 'text/javascript';
# rct.async = true;
# rct.src = (document.location.protocol === 'https:' ? 'https:' : 'http:') + '//ads.rubiconproject.com/header/' + account_id + '.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.appendChild(rct);
# })();
#
# </script><script type="text/javascript" src="//reuters-d.openx.net/w/1.0/jstag?nc=4735792-reuters"></script><div class="linebreak"></div>
# <style>
# @font-face { font-family: 'knowledge-reg'; src: url('/resources_v2/fonts/Knowledge-Regular.woff') format('woff'); font-weight: normal; font-style: normal; }
# @font-face { font-family: 'knowledge-light'; src: url('/resources_v2/fonts/Knowledge-Light.woff') format('woff'); font-weight: normal; font-style: normal; }
# @font-face { font-family: 'knowledge-medium'; src: url('/resources_v2/fonts/Knowledge-Medium.woff') format('woff'); font-weight: normal; font-style: normal; }
# </style>
#
# <script type="text/javascript" src="//www.reuters.com/reuters_bootstrap.js"></script><script type="text/javascript" src="//www.reuters.com/reuters_gpt_bootstrap.js"></script>
# <script type="text/javascript">var abp;</script><script type="text/javascript" src="https://s4.reutersmedia.net/resources_v2/js/px.js?ch=1"></script><script type="text/javascript" src="https://s4.reutersmedia.net/resources_v2/js/px.js?ch=2"></script>
# <script type="text/javascript">
# var parallelMediaHosts = new Array();
# parallelMediaHosts.push("s1.reutersmedia.net");parallelMediaHosts.push("s2.reutersmedia.net");parallelMediaHosts.push("s3.reutersmedia.net");parallelMediaHosts.push("s4.reutersmedia.net");</script>
#
# <meta name="site edition" content="Reuters" />
# <link rel="canonical" href="http://www.reuters.com/news/archive/worldNews" />
# <meta name="Author" content="Reuters Editorial" />
# <meta name="description" content="Get the latest breaking news and top news headlines at Reuters.com" />
# <meta name="keywords" content="top news,breaking news,latest news,news headlines" />
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:description" content="Get the latest breaking news and top news headlines at Reuters.com" />
# <meta name="twitter:image:src" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png">
# <meta name="twitter:image" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png" />
# <meta name="twitter:site" content="@Reuters" />
# <meta name="twitter:creator" content="@Reuters" />
# <link rel="publisher" href="https://plus.google.com/+Reuters" />
# <meta property="og:locale" content="en_US" />
# <meta property="og:site_name" content="Reuters" />
# <meta property="og:title" content="Breaking News, Top News & Latest News Headlines | Reuters" />
# <meta property="og:url" content="http://www.reuters.com/news/archive/worldNews" />
# <meta property="og:type" content="section" />
# <meta property="og:description" content="Get the latest breaking news and top news headlines at Reuters.com" />
# <meta property="og:image" content="https://s4.reutersmedia.net/resources_v2/images/rcom-default.png"/>
# <meta property="article:publisher" content="https://www.facebook.com/Reuters" />
#
# <script type="application/ld+json">
# {
# "@context": "http://schema.org",
# "@type": "WebPage",
# "headline": "Breaking News, Top News & Latest News Headlines | Reuters",
# "url": "http://www.reuters.com/news/archive/worldNews",
# "thumbnailUrl": "",
# "dateCreated": "",
# "description": "Get the latest breaking news and top news headlines at Reuters.com",
# "publisher": "Reuters",
# "creator": [],
# "keywords": ["top news","breaking news","latest news","news headlines","World"]
# }
# </script>
# <meta name="DCSext.rChannel" content="Article - News">
#
# <meta name="DCSext.ContentChannel"  content="Default">
# <meta name="DCSext.ContentType"  content="Archive">
# <meta name="DCSext.DartZone" content="us.reuters/world/article_archive" />
# <meta name="WT.cg_n" content="World">
# <meta name="WT.cg_s" content="World">
# <link rel="shortcut icon" type="image/x-icon" href="//s3.reutersmedia.net/resources_v2/images/favicon/favicon.ico" />
# <link rel="icon" type="image/png" href="//s3.reutersmedia.net/resources_v2/images/favicon/favicon-16x16.png" sizes="16x16" />
# <link rel="icon" type="image/png" href="//s1.reutersmedia.net/resources_v2/images/favicon/favicon-32x32.png" sizes="32x32" />
# <link rel="icon" type="image/png" href="//s3.reutersmedia.net/resources_v2/images/favicon/favicon-96x96.png" sizes="96x96" />
# <link rel="stylesheet" type="text/css" href="//s2.reutersmedia.net/resources_v2/css/core.css" />
# <link rel="stylesheet" type="text/css" href="//s4.reutersmedia.net/resources_v2/css/core-modules.css" />
# <script src="//s3.reutersmedia.net/resources_v2/js/libraries/jquery-2.2.4.min.js" type="text/javascript"></script>
#
# <style>
# .column2 .module {
# display: inline-block;
# width: 100%;
# margin: 0 0 20px 0;
# }
#
# .column2 .module .moduleHeader {
# margin: 0;
# }
#
# .column2 .module .moduleHeader {
# background: #333;
# padding: 8px 0;
# }
#
# .column2 .module .moduleHeader h3 {
# font-size: 16px;
# font-weight: bold;
# text-transform: uppercase;
# margin: 0 10px;
# padding: 0;
# color: #FFF;
# text-align: left;
# }
#
# .column2 .module .moduleHeader h3 a {
# color: #FFF;
# }
#
# .column2 .module .moduleBody {
# padding-top: 8px;
# }
#
# .column2 .module .moduleBody h2 {
# font-family: knowledge, helvetica, arial, sans-serif;
# font-weight: 500;
# font-size: 1.8em;
# line-height: 20px;
# }
#
# .column2 .module .moduleBody .feature .photo {
# float: left;
# margin: 0 8px 8px 0;
# }
#
# .column2 .module .moduleBody ul {
# list-style: none;
# padding-left: 15px;
# margin-bottom: 18px;
# }
#
# .column2 .module .moduleBody li {
# padding-bottom: 8px;
# list-style: none;
# font-family: knowledge, helvetica, arial, sans-serif;
# font-weight: 500;
# font-size: 1.4em;
# line-height: 18px;
# }
#
# .column2 .module .moduleBody li:before {
# color: #ff8000;
# content: "\2022";
# font-size: 1.5em;
# margin-left: -15px;
# padding-right: 5px;
# vertical-align: top;
# }
#
# .column2 .module .moduleBody li .info {
# display: inline-block;
# }
#
# .column2 .module .moreLink {
# text-align: right;
# font-size: 1.2em;
# }
# </style><script src="//s2.reutersmedia.net/resources_v2/js/libraries/cookie.js" type="text/javascript"></script>
# <script src="//s2.reutersmedia.net/resources_v2/js/core.js" type="text/javascript"></script>
# <script src="//s2.reutersmedia.net/resources_v2/js/search.js" type="text/javascript"></script>
# <script type='text/javascript'>
# var _sf_async_config = _sf_async_config || {};
# _sf_async_config.uid = 52639;
# _sf_async_config.domain = 'reuters.com';
# _sf_async_config.topStorageDomain = 'reuters.com';
# _sf_async_config.path = document.querySelector("link[rel='canonical']").getAttribute("href").replace('http://www.', '');
# _sf_async_config.flickerControl = false;
# var _sf_startpt = (new Date()).getTime();
# </script><script async src='//static.chartbeat.com/js/chartbeat_mab.js'></script></head>
# <body class="BETAUS archive">
# <!-- New Google Tag Manager (noscript) -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-W9SLGS"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#
# <section id="breakingNewsContainer" class="hidden"><div id="breakingNews" class="group wrap"><div class="breaking-content"><div class="breaking-news-type"></div><div class="breaking-news-content"></div></div><div class="close-btn">X</div></div></section>
#
# <header id="headerMain">
# <div class="container group">
# <div class="edition-container group">
# <div class="edition-label">Edition:</div>
# <div class="edition-selector">
# <div class="edition">United States</div>
# <div class="edition-arrow"></div>
# </div>
# </div>
# <div class="reuters-nav-main">
# <h2 class="reuters-logo">
# <a href="/" title="Reuters"></a>
# </h2>
# </div>
# <div id="utilities" class="utilities"></div>
# </div>
# </header>
# <nav id="headerNav">
# <div class="container group">
# <div class="header-mini-logo">
# <a href="/" title="Reuters"></a>
# </div>
# <ul class="horizontal-list nav-list">
# <li class="nav-item home-tab active-icon
# no-subnav" id="nav-item-1">
# <a href="/home" class="nav-link-sec">
# <div class="home-icon"></div>
# <span class="text"></span>
# </a>
# </li>
# <li class="nav-item" id="nav-item-2">
# <a href="/finance" class="nav-link-sec">Business</a>
# <div class="subnav" id="subnav-2">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/finance" class="nav-link-subsec">Business Home</a></li>
# <li><a href="/legal" class="nav-link-subsec">Legal</a></li>
# <li><a href="/finance/deals" class="nav-link-subsec">Deals</a></li>
# <li><a href="/subjects/aerospace-and-defense" class="nav-link-subsec">Aerospace & Defense</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/subjects/banks" class="nav-link-subsec">Finance</a></li>
# <li><a href="/subjects/autos" class="nav-link-subsec">Autos</a></li>
# <li><a href="/finance/summits" class="nav-link-subsec">Reuters Summits</a></li>
# <li><a href="/news/subjects/ADventures" class="nav-link-subsec">ADventures</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/data-dive" class="nav-link-subsec">Data Dive</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-3">
# <a href="/finance/markets" class="nav-link-sec">Markets</a>
# <div class="subnav" id="subnav-3">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/finance/markets" class="nav-link-subsec">Markets Home</a></li>
# <li><a href="/finance/markets/us" class="nav-link-subsec">U.S. Markets</a></li>
# <li><a href="/finance/markets/europe" class="nav-link-subsec">European Markets</a></li>
# <li><a href="/finance/markets/asia" class="nav-link-subsec">Asian Markets</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/finance/global-market-data" class="nav-link-subsec">Global Market Data</a></li>
# <li><a href="/finance/markets/indices" class="nav-link-subsec">Stocks</a></li>
# <li><a href="/finance/bonds" class="nav-link-subsec">Bonds</a></li>
# <li><a href="/finance/currencies" class="nav-link-subsec">Currencies</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/finance/commodities" class="nav-link-subsec">Commodities</a></li>
# <li><a href="/finance/futures" class="nav-link-subsec">Futures</a></li>
# <li><a href="/finance/funds" class="nav-link-subsec">Funds</a></li>
# <li><a href="/finance/EarningsUS" class="nav-link-subsec">Earnings</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/finance/markets/dividends" class="nav-link-subsec">Dividends</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-4">
# <a href="/news/world" class="nav-link-sec">World</a>
# <div class="subnav" id="subnav-4">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/news/world" class="nav-link-subsec">World Home</a></li>
# <li><a href="/news/us" class="nav-link-subsec">U.S.</a></li>
# <li><a href="/subjects/specialReports" class="nav-link-subsec">Special Reports</a></li>
# <li><a href="http://www.reuters.com/investigates/" class="nav-link-subsec">Reuters Investigates</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/subjects/euro-zone" class="nav-link-subsec">Euro Zone</a></li>
# <li><a href="/subjects/middle-east" class="nav-link-subsec">Middle East</a></li>
# <li><a href="/places/china" class="nav-link-subsec">China</a></li>
# <li><a href="/places/japan" class="nav-link-subsec">Japan</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/places/mexico" class="nav-link-subsec">Mexico</a></li>
# <li><a href="/places/brazil" class="nav-link-subsec">Brazil</a></li>
# <li><a href="/places/africa" class="nav-link-subsec">Africa</a></li>
# <li><a href="/places/russia" class="nav-link-subsec">Russia</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/places/india" class="nav-link-subsec">India</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-5">
# <a href="/politics" class="nav-link-sec">Politics</a>
# <div class="subnav" id="subnav-5">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/politics" class="nav-link-subsec">Politics Home</a></li>
# <li><a href="http://polling.reuters.com" class="nav-link-subsec">Polling Explorer</a></li>
# <li><a href="http://live.reuters.com/Event/Live_US_Politics" class="nav-link-subsec">Live: U.S. Politics</a></li>
# <li><a href="/subjects/supreme-court" class="nav-link-subsec">Supreme Court</a></li>
# </ul>
# <ul class="subnav-list">
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-6">
# <a href="/news/technology" class="nav-link-sec">Tech</a>
# <div class="subnav" id="subnav-6">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/news/technology" class="nav-link-subsec">Technology Home</a></li>
# <li><a href="/news/science" class="nav-link-subsec">Science</a></li>
# <li><a href="/bizfinance/technology/Top100Innovators" class="nav-link-subsec">Top 100 Global Innovators</a></li>
# <li><a href="/news/media" class="nav-link-subsec">Media</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/news/environment" class="nav-link-subsec">Environment</a></li>
# <li><a href="/innovation" class="nav-link-subsec">Innovation</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-7">
# <a href="/commentary" class="nav-link-sec">Commentary</a>
# <div class="subnav" id="subnav-7">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/commentary" class="nav-link-subsec">Commentary Home </a></li>
# <li><a href="/tools/podcasts/" class="nav-link-subsec">Podcasts</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-8">
# <a href="/breakingviews" class="nav-link-sec">Breakingviews</a>
# <div class="subnav" id="subnav-8">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/breakingviews" class="nav-link-subsec">Breakingviews Home</a></li>
# <li><a href="/video/breakingviews" class="nav-link-subsec">Breakingviews Video</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-9">
# <a href="/finance/personal-finance" class="nav-link-sec">Money</a>
# <div class="subnav" id="subnav-9">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/finance/personal-finance" class="nav-link-subsec">Money Home</a></li>
# <li><a href="/finance/personal-finance/retirement" class="nav-link-subsec">Retirement</a></li>
# <li><a href="/subjects/us-lipper-awards" class="nav-link-subsec">Lipper Awards</a></li>
# <li><a href="/finance/personal-finance/analyst-research" class="nav-link-subsec">Analyst Research</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="http://stockscreener.us.reuters.com/Stock/US/Index?quickscreen=gaarp" class="nav-link-subsec">Stock Screener</a></li>
# <li><a href="http://funds.us.reuters.com/US/screener/screener.asp" class="nav-link-subsec">Fund Screener</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item" id="nav-item-10">
# <a href="/news/lifestyle" class="nav-link-sec">Life</a>
# <div class="subnav" id="subnav-10">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/news/health" class="nav-link-subsec">Health</a></li>
# <li><a href="/news/sports" class="nav-link-subsec">Sports</a></li>
# <li><a href="/news/entertainment/arts" class="nav-link-subsec">Arts</a></li>
# <li><a href="/news/entertainment" class="nav-link-subsec">Entertainment</a></li>
# </ul>
# <ul class="subnav-list">
# <li><a href="/news/oddlyEnough" class="nav-link-subsec">Oddly Enough</a></li>
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item pictures-tab active-icon active-text
# " id="nav-item-11">
# <a href="/news/pictures" class="nav-link-sec">
# <div class="pictures-icon"></div>
# <span class="text">Pictures</span>
# </a>
# <div class="subnav" id="subnav-11">
# <div class="subnav-inset">
# <ul class="subnav-list">
# <li><a href="/news/pictures" class="nav-link-subsec">Pictures Home</a></li>
# <li><a href="http://widerimage.reuters.com" class="nav-link-subsec">The Wider Image</a></li>
# <li><a href="http://widerimage.reuters.com/photographer" class="nav-link-subsec">Photographers</a></li>
# <li><a href="/focus-360/" class="nav-link-subsec">Focus 360</a></li>
# </ul>
# <ul class="subnav-list">
# </ul>
# </div>
# </div>
# </li>
# <li class="nav-item video-tab active-icon active-text
# no-subnav" id="nav-item-12">
# <a href="/video" class="nav-link-sec">
# <div class="video-icon"></div>
# <span class="text">Video</span>
# </a>
# </li>
# <li class="nav-item search-tab active-icon no-subnav"><div class="search-icon"></div></li>
# </ul>
# <div id="searchBar">
# <form id="searchForm" class="search-form" name="searchbox" method="get" action="/search/news" autocomplete="off">
# <input id="searchfield" class="search-field" name="blob" type="text" value="" onfocus="this.value = this.value;"  size="30" maxlength="128">
# <span class="search-line"></span>
# <input type="submit" id="search-submit-button" class="search-submit-button" value="" onmousedown="if(document.forms['searchbox'].blob.value == 'Search Reuters') { document.forms['searchbox'].blob.value = ''; }">
# <div class="search-close-button"></div>
# </form>
# </div>
# </div>
# </nav>
# <div class="nav-white-space"></div>
# <div class="edition-header">
# <div class="container">
# <div class="selection-header"></div>
# <ul class="edition-list">
# <li>
# <div class="item"><a href="//af.reuters.com">Africa</a></div>
# <div class="item"><a href="//lta.reuters.com">América Latina</a></div>
# </li>
# <li>
# <div class="item"><a href="//ara.reuters.com">عربي</a></div>
# <div class="item"><a href="//ar.reuters.com">Argentina</a></div>
# </li>
# <li>
# <div class="item"><a href="//br.reuters.com">Brasil</a></div>
# <div class="item"><a href="//ca.reuters.com">Canada</a></div>
# </li>
# <li>
# <div class="item"><a href="//cn.reuters.com" class="">中国</a></div>
# <div class="item"><a href="//de.reuters.com" class="">Deutschland</a></div>
# </li>
# <li>
# <div class="item"><a href="//es.reuters.com">España</a></div>
# <div class="item"><a href="//fr.reuters.com">France</a></div>
# </li>
# <li>
# <div class="item"><a href="//in.reuters.com" class="">India</a></div>
# <div class="item"><a href="//it.reuters.com">Italia</a></div>
# </li>
# <li>
# <div class="item"><a href="//jp.reuters.com" class="">日本</a></div>
# <div class="item"><a href="//mx.reuters.com">México</a></div>
# </li>
# <li>
# <div class="item"><a href="//ru.reuters.com">РОССИЯ</a></div>
# <div class="item"><a href="//uk.reuters.com" class="">United Kingdom</a></div>
# </li>
# <li><div class="item"><a href="//www.reuters.com" class="active">United States</a></div></li>
# </ul>
# </div>
# </div>
#
# <div id="content">
# <div id="overlayForSearch"></div><section class="ad-horizontal">
# <div class="group wrap" id="bannerStrip">
# <div id="div_gpt_lb" class="ad-leaderboard"><script>
# gatherAd('div_gpt_lb', [[728, 90],[970,250],[970,180],[970,90],[1,1]], TR3.extractDartZone(), 'yes', 'leaderboard');
# </script></div>
#
# <div class="linebreak"></div>
# </div>
# </section><section>
# <div class="group wrap" id="">
# <div class="column1 col col-10">
# <div id="sectionTitle"><header class="module-header ">
# <h4 class="module-heading">
# World News <span class="title-last">Headlines</span>
# </h4>
# </header>
# </div><section  class="module  ">
#
# <section class="module-content">
# <div class="news-headline-list medium">
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-usa-navy-asia-idUSKBN1972SW">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s2.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189403538&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G08D"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-usa-navy-asia-idUSKBN1972SW">
# <h3 class="story-title">
# Seven sailors missing after U.S. Navy destroyer collides with container ship off Japan</h3>
# </a>
# <div class="contributor"></div>
# <p>Search and rescue efforts went on after dark for seven U.S. sailors missing after the U.S. Navy destroyer USS Fitzgerald collided with a Philippine-flagged container ship more than three times its size off eastern Japan early on Saturday.</p>
# <time class="article-time">
# <span class="timestamp">9:27am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-russia-usa-sanctions-idUSKBN1980CF">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s4.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189402655&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G07W"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-russia-usa-sanctions-idUSKBN1980CF">
# <h3 class="story-title">
# Putin: more U.S. sanctions would be harmful, talk of retaliation premature</h3>
# </a>
# <div class="contributor"></div>
# <p>Russian President Vladimir Putin said new sanctions under consideration by the United States would damage relations between the two countries, but it was too early to talk about retaliation, state news agency RIA reported on Saturday.</p>
# <time class="article-time">
# <span class="timestamp">7:14am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo  ">
# <a href="/article/us-afghanistan-attack-idUSKBN1980HJ">
# <img class="placeholder-image" src="//s1.reutersmedia.net/resources_v2/images/1x1.png" border="0" alt="" />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-afghanistan-attack-idUSKBN1980HJ">
# <h3 class="story-title">
# Four U.S. soldiers killed in apparent insider attack in Afghanistan: official</h3>
# </a>
# <div class="contributor"></div>
# <p>At least four American soldiers were shot and killed in an apparent insider attack by an Afghan soldier at a base in northern Afghanistan on Saturday, a military official said.</p>
# <time class="article-time">
# <span class="timestamp">9:10am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-yemen-security-hodeidah-idUSKBN1980G0">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s2.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189409676&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0C4"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-yemen-security-hodeidah-idUSKBN1980G0">
# <h3 class="story-title">
# Yemen government agrees to U.N. Hodeidah plan, Houthis skeptical</h3>
# </a>
# <div class="contributor"></div>
# <p>Yemen's Saudi-backed government said on Saturday it agreed to a two-point plan advanced by the United Nations to ease suffering in the country's civil war, but the Iran-aligned Houthi movement remained skeptical.</p>
# <time class="article-time">
# <span class="timestamp">8:38am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-pope-merkel-idUSKBN1980HW">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s1.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189411965&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0D2"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-pope-merkel-idUSKBN1980HW">
# <h3 class="story-title">
# Pope tells Merkel to keep pressing for international cooperation</h3>
# </a>
# <div class="contributor"></div>
# <p>Pope Francis has asked Germany to keep fighting for the Paris climate change deal and to 'tear down walls' that inhibit international cooperation, Chancellor Angela Merkel said on Saturday, offering a stark contrast between her agenda and U.S. policy.</p>
# <time class="article-time">
# <span class="timestamp">9:25am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-philippines-militants-idUSKBN1980EE">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s1.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189407317&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0B0"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-philippines-militants-idUSKBN1980EE">
# <h3 class="story-title">
# Duterte resurfaces after rest, says battle with militants winding down</h3>
# </a>
# <div class="contributor"></div>
# <p>President Rodrigo Duterte of the Philippines, who had avoided public appearances for nearly a week to recover from what spokesmen described as fatigue, said on Saturday that a battle with Islamist militants in Marawi City was winding down, but the insurgency had deep roots.</p>
# <time class="article-time">
# <span class="timestamp">7:55am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-mideast-crisis-syria-un-idUSKBN1980DP">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s2.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189406084&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0AE"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-mideast-crisis-syria-un-idUSKBN1980DP">
# <h3 class="story-title">
# U.N. mediator targets fresh Syria talks for July 10</h3>
# </a>
# <div class="contributor"></div>
# <p>The United Nations special mediator for Syria, Staffan de Mistura, wants to start a fresh round of talks between Syrian factions on July 10, his office said on Saturday.</p>
# <time class="article-time">
# <span class="timestamp">8:51am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo  ">
# <a href="/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y">
# <img class="placeholder-image" src="//s1.reutersmedia.net/resources_v2/images/1x1.png" border="0" alt="" />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-mideast-crisis-iraq-syria-idUSKBN19807Y">
# <h3 class="story-title">
# Iraqi forces remove Islamic State fighters from vicinity of U.S.base in Syria</h3>
# </a>
# <div class="contributor"></div>
# <p>The Iraqi army and Sunni tribal fighters have dislodged Islamic State from the al-Waleed border crossing into Syria, an Iraqi military statement said on Saturday.</p>
# <time class="article-time">
# <span class="timestamp">9:05am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-egypt-court-idUSKBN198096">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s4.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189405089&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G09T"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-egypt-court-idUSKBN198096">
# <h3 class="story-title">
# Egyptian court recommends death penalty for 30 over assassination of prosecutor</h3>
# </a>
# <div class="contributor"></div>
# <p>A Cairo criminal court on Saturday recommended the death penalty for 30 people convicted of involvement in the 2015 assassination of Egypt's top prosecutor, the most senior state official killed by militants in recent years.</p>
# <time class="article-time">
# <span class="timestamp">7:20am EDT</span>
# </time>
# </div>
#
# </article>
# <article class="story ">
# <div class="story-photo lazy-photo ">
# <a href="/article/us-britain-fire-idUSKBN1980CY">
# <img
#
# src="//s1.reutersmedia.net/resources_v2/images/1x1.png"
# org-src="https://s3.reutersmedia.net/resources/r/?m=02&d=20170617&t=2&i=1189406546&w=200&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5G0AK"
#
# border="0" alt=""
# />
# </a>
# </div>
# <div class="story-content">
# <a href="/article/us-britain-fire-idUSKBN1980CY">
# <h3 class="story-title">
# British PM May tries to quell public anger after deadly London fire</h3>
# </a>
# <div class="contributor"></div>
# <p>British Prime Minister Theresa May's government sought on Saturday to quell anger over a deadly tower block fire by pledging to support the victims of the blaze after protesters jeered her when she visited local residents.</p>
# <time class="article-time">
# <span class="timestamp">9:35am EDT</span>
# </time>
# </div>
#
# </article>
# </div>
# </section>
# </section>
#
# <div class="control-nav" data-page='1' data-page-size="10" data-type='' data-more='false'>
# <span class="control-nav-prev control-nav-disabled"></span>
# <span class="control-nav-next control-nav-disabled">Earlier</span>
# </div>
#
#
# <div class="linebreak"></div>
# </div>
#
# <div class="column2 col col-4">
# <div class="module">
#
# <div class="moduleHeader">
# <h3>
# <a href="/news/video?videoChannel=1003" >
# Politics Video</a>
# </h3>
# </div>
# <div class="moduleBody">
# <div class="mediaList videoList size300">
# <div class="feature"><div class="photo">
# <a href="/news/video/story?videoId=371909343&videoChannel=1003"  >
# <div class="videoOverlay"></div>
# <img
#
# src="https://s3.reutersmedia.net/resources/r/?d=20170616&i=129819935&w=300&r=129819935-1&t=2"
#
# border="0" alt="Trump orders clampdown on Cuba travel and trade"
# />
# </a>
# </div><h2><a href="/news/video/story?videoId=371909343&videoChannel=1003"  >Trump orders clampdown on Cuba travel and trade</a>
# </h2></div><ul><li><div class="info"><a href="/news/video/story?videoId=371909293&videoChannel=1003"  >Scalise showing improvement after being shot: lead surgeon</a>
# </div><div class="linebreak"></div></li><li><div class="info"><a href="/news/video/story?videoId=371909058&videoChannel=1003"  >Trump clamps down on Cuba travel</a>
# </div><div class="linebreak"></div></li><li><div class="info"><a href="/news/video/story?videoId=371907943&videoChannel=1003"  >What happened to Warmbier a "truly terrible thing": Trump</a>
# </div><div class="linebreak"></div></li></ul></div><!-- end mediaList -->
# <div class="moreLink">
# <a href="/news/video?videoChannel=1003">&#187; More Politics Video</a></div></div>
# </div>
#
#
# <div id="div_gpt_mpu"><script>
# gatherAd('div_gpt_mpu', [[300, 250],[300,600],[300,1050]], TR3.extractDartZone(), 'yes', 'mpu');
# </script></div><div class="linebreak"></div>
#
#
# <div class="module">
#
# <div class="moduleHeader">
# <h3>
# <a href="http://www.reuters.com/politics" >
# Politics News</a>
# </h3>
# </div>
# <div class="moduleBody">
# <div class="feature"><div class="photo">
# <a href="/article/us-usa-cuba-idUSKBN1970EC"  ><img
#
# src="https://s3.reutersmedia.net/resources/r/?m=02&d=20170616&t=2&i=1189335626&w=300&fh=&fw=&ll=&pl=&sq=&r=LYNXMPED5F1UQ"
#
# border="0" alt="Photo"
# /></a>
# </div><h2><a href="/article/us-usa-cuba-idUSKBN1970EC"  >Trump rolls back parts of what he calls 'terrible' Obama Cuba policy</a>
# </h2><p>MIAMI President Donald Trump on Friday ordered tighter restrictions on Americans traveling to Cuba and a clampdown on U.S. business dealings with the Caribbean island’s military, saying he was canceling former President Barack Obama's "terrible and misguided deal" with Havana. |&nbsp;<span class="inlineLinks"><a href="/video/2017/06/16/trump-clamps-down-on-cuba-travel?videoId=371909058&newsChannel=politicsNews"  >Video</a>
# </span></p>
# </div><ul>
# <li><a href="/article/us-usa-trump-ethics-idUSKBN1972XM"  >Trump owes lenders at least $315 million, disclosure shows</a>
# </li><li><a href="/article/us-usa-trump-russia-ukraine-idUSKBN1971TT"  >Trump acknowledges he is under investigation in Russia probe</a>
# </li><li><a href="/article/us-usa-trump-russia-lawyer-idUSKBN19800X"  >Trump adds Washington lawyer John Dowd to his legal team</a>
# </li></ul>
# <div class="moreLink">
# <a href="http://www.reuters.com/politics">&#187; More</a></div></div>
# </div>
# <script>
# var topStoryGrid = $('#topStory').find('.grid8');
# if (topStoryGrid.hasClass('grid8')) {
# if ($('#latestHeadlines')) {
# $('#latestHeadlines').remove();
# }
# };
# </script>
#
#
# <div id="div_gpt_mpulow"><script>
# gatherAd('div_gpt_mpulow', [[300, 250],[300,600],[300,1050]], TR3.extractDartZone(), 'yes', 'mpulow');
# </script></div>
#
# </div>
#
# </div>
# </section><section class="ad-horizontal">
# <div class="group wrap" id="">
# <div id="div_gpt_lb_center" class="ad-leaderboard"><script>
# gatherAd('div_gpt_lb_center', [[728, 90],[970,250],[970,180],[970,90],[970,66],[1,1]], TR3.extractDartZone(), 'yes', 'leaderboardcenter');
# </script></div>
#
# <div class="linebreak"></div>
# </div>
# </section></div>
# <footer>
# <section class="footer">
# <div class="group wrap" id="">
# <script>
#
# callAds();
# </script>
# <div id="section-follow-buttons"><span class="footer-follow">Follow Reuters: </span>
# <ul>
# <li id="foot-twitter"><a href="//www.twitter.com/reuters" target="_blank"><span class="follow-button follow-twitter">Follow Us On Twitter</span></a></li>
# <li id="foot-facebook"><a href="//www.facebook.com/Reuters" target="_blank"><span class="follow-button follow-facebook">Follow Us On Facebook</span></a></li>
# <li id="foot-rssfeed"><a href="//www.reuters.com/tools/rss" target="_blank"><span class="follow-button follow-rss">Follow Us On RSS</span></a></li>
# <li id="foot-instagram"><a href=" //instagram.com/reuters/" target="_blank"><span class="follow-button follow-instagram">Follow Us On Instagram</span></a></li>
# <li id="foot-youtube"><a href="//www.youtube.com/user/ReutersVideo" target="_blank"><span class="follow-button follow-youtube">Follow Us On YouTube</span></a></li>
# <li id="foot-linkedin"><a href="//www.linkedin.com/company/thomson-reuters_1400" target="_blank"><span class="follow-button follow-linkedin">Follow Us On LinkedIn</span></a></li>
# </ul></div><div class="footer-more-links"><span class="footer-more">Subscribe: </span>
# <a href="//www.reuters.com/tools/rss">Feeds</a> | <a href="//newslink.reuters.com/join/subscribe">Newsletters</a> | <a href="/tools/podcasts">Podcasts</a> | <a href="/tools/mobile">Apps</a> </div></div>
# </section><section class="footer-body">
# <div class="group wrap" id="">
# <div class="footer-services-link"><a href="//agency.reuters.com" target="_blank">Reuters News Agency</a> | <a href="//agency.reuters.com/en/platforms-delivery/reuters-brand-attribution-guidelines.html" target="_blank">Brand Attribution Guidelines</a>  | <a href="//thomsonreuters.com/en/careers.html" target="_blank">Careers</a></div><div class="disclaimer"><div class="footer-summary">
# <p>Reuters is the news and media division of <a href="//thomsonreuters.com/" target="_blank">Thomson Reuters</a>. Thomson Reuters is the world's largest international multimedia news agency, providing investing news, world news, business news, technology news, headline news, small business news, news alerts, personal finance, stock market, and mutual funds information available on Reuters.com, video, mobile, and interactive television platforms. Learn more about Thomson Reuters products:</p>
# </div></div><div class="product-container">
# <a href="//financial.thomsonreuters.com/en/products/tools-applications/trading-investment-tools/eikon-trading-software.html" target="_blank">
# <div class="product">
# <div class="prod-title">Eikon</div>
# <div class="prod-content">Information, analytics and exclusive news on financial markets - delivered in an intuitive desktop and mobile interface
# </div>
# </div>
# </a>
# <a href="//financial.thomsonreuters.com/en/products/infrastructure/trading-infrastructure/elektron-enterprise-data-management.html" target="_blank">
# <div class="product">
# <div class="prod-title">Elektron</div>
# <div class="prod-content">Everything you need to empower your workflow and enhance your enterprise data management
# </div>
# </div>
# </a>
# <a href="//risk.thomsonreuters.com/products/world-check" target="_blank">
# <div class="product">
# <div class="prod-title">World-Check</div>
# <div class="prod-content">Screen for heightened risk individual and entities globally to help uncover hidden risks in business relationships and human networks
# </div>
# </div>
# </a>
# <a href="//legalsolutions.thomsonreuters.com/law-products/westlaw-legal-research/" target="_blank">
# <div class="product">
# <div class="prod-title">Westlaw</div>
# <div class="prod-content">Build the strongest argument relying on authoritative content, attorney-editor expertise, and industry defining technology
# </div>
# </div>
# </a>
# <a href="//tax.thomsonreuters.com/products/brands/onesource/" target="_blank">
# <div class="product">
# <div class="prod-title">ONESOURCE</div>
# <div class="prod-content">The most comprehensive solution to manage all your complex and ever-expanding tax and compliance needs
# </div>
# </div>
# </a>
# <a href="//tax.thomsonreuters.com/products/brands/checkpoint/" target="_blank">
# <div class="product prod-last">
# <div class="prod-title">CHECKPOINT</div>
# <div class="prod-content">The industry leader for online information for tax, accounting and finance professionals
# </div>
# </div>
# </a>
# </div><div class="linebreak"></div>
# <div class="footer-policy-links"><p> All quotes delayed a minimum of 15 minutes. <a href="/info/disclaimer">See here for a complete list</a> of exchanges and delays.</p>
# <div class="footer-policies"><ul>
#
# <li class="h-links">
# <div class="reuters-copyright"><script type="text/javascript">var year = new Date();document.write('<a href="//thomsonreuters.com/copyright/">&copy;  ' + year.getFullYear() + ' Reuters. All Rights Reserved.</a>');</script></div>
# </li>
# <li class="h-links"><a href="//reuters.zendesk.com/" target="_blank">Site Feedback</a></li>
# <li class="h-links"><a href="https://reuters.zendesk.com/anonymous_requests/new" target="_blank">Corrections</a></li>
# <li class="h-links"><a href="/advertising-guidelines">Advertising Guidelines</a></li>
# <li class="h-links"><a href="//info.evidon.com/pub_info/285" target="_blank">Cookies</a></li>
# <li class="h-links"><a href="/terms-of-use">Terms of Use</a></li>
# <li class="h-links h-links-last"><a href="/privacy-policy">Privacy Policy</a></li>
#
# </ul></div></div></div>
# </section>
#
# </footer>
#
# <script src="//s4.reutersmedia.net/resources_v2/js/core-header.js" type="text/javascript"></script>
# <script src="//s3.reutersmedia.net/resources_v2/js/core-login.js" type="text/javascript"></script>
# <script src="//s2.reutersmedia.net/resources_v2/js/core-tracking.js" type="text/javascript"></script>
# <script src="//s2.reutersmedia.net/resources_v2/js/rcom-social-share.js" type="text/javascript"></script>
# <script src="//s2.reutersmedia.net/resources_v2/js/libraries/core-lib.js" type="text/javascript"></script>
# <script src="//s4.reutersmedia.net/resources_v2/js/core-modules.js" type="text/javascript"></script>
# <script>
# if(window.location.href.indexOf("BigStory14") > -1 ){
# $(document).prop('title', 'Rio 2016 Headlines');
# //$("div#sectionTitle header").contents().filter(function(){ return this.nodeType == 1; }).filter(':first').text("RIO 2016").append('<span class=title-last> Headlines</span>');
#
# }
# </script><script language="javascript" type="text/javascript" src="//www.reuters.com/reuters_gpt_bootstrap_footer.js"></script>
#
# <script type="text/javascript">
# $(document).ready( function() {
# var sclTracking = new rcom_scrollTracker("Archive");
# if( inAppleMobileDevice() ) {document.addEventListener("scroll", sclTracking, false);} else {$(window).scroll( sclTracking );}
# });
# </script>
#
# <section>
# <div class="group" id="">
# <script type='text/javascript'>
# var _sf_startpt = (new Date()).getTime();
# var _sf_async_config = _sf_async_config || {};
#
# _sf_async_config.playerdomain = 'queso-cdn.prod.reuters.tv';
# _sf_async_config.sections = 'World';
# _sf_async_config.autoDetect = false;
#
# _sf_async_config.authors = 'Reuters Editorial';
# _sf_async_config.type = 'Archive';
#
# (function(){
# function loadChartbeat() {
# window._sf_endpt=(new Date()).getTime();
# var e = document.createElement('script');
# e.setAttribute('language', 'javascript');
# e.setAttribute('type', 'text/javascript');
# e.setAttribute('src', '//static.chartbeat.com/js/chartbeat_video.js');
# document.body.appendChild(e);
# }
# var oldonload = window.onload;
# window.onload = (typeof window.onload != 'function') ?
# loadChartbeat : function() { oldonload(); loadChartbeat(); };
# })();
# </script>
# </div>
# </section>
#
# </body>
# </html>

# %%
content2 = request.urlopen(url).read()
soup2= BeautifulSoup(content2, 'html.parser')

# %% [markdown]
# The rest of the part where we use beautifulsoup to extract specific data is equivalent to method 1 above
